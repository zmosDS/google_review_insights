# %%
# Libraries
import json
import pandas as pd

# %%
# Json import function to handle errors or bad rows
def load_jsonl_safe(path, max_errors=20):
    records = []
    errors = 0

    with open(path, "r", encoding="utf-8", errors="replace") as f:
        for i, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            try:
                records.append(json.loads(line))
            except json.JSONDecodeError:
                errors += 1
                if errors <= max_errors:
                    print(f"Skipping bad JSON at line {i}")
                if errors > max_errors:
                    print("Too many errors, suppressing further messages")
                    break

    print(f"Loaded {len(records)} records with {errors} bad lines skipped")
    return pd.DataFrame(records)

# %%
# Loads the 5% sample data
reviews_df = load_jsonl_safe("../../sampled_data/review_California_5pct.json")
meta_df = load_jsonl_safe("../../sampled_data/meta_California_5pct.json")

reviews_df.shape, meta_df.shape
# Out:
# Skipping bad JSON at line 380129
# Loaded 380129 records with 1 bad lines skipped
# Skipping bad JSON at line 7318
# Loaded 7318 records with 1 bad lines skipped
# ((380129, 8), (7318, 15))

# %%
reviews_df.head()
# Out:
#                  user_id               name           time  rating  \
# 0  101226371370637614545  Faranak Rafizadeh  1618261672851     5.0
# 1  112640357449611959087          David Han  1583643882296     4.0
# 2  100185732664454906803        Ana Salazar  1547799582640     5.0
# 3  111125108075765074122         kimchi lee  1492967841515     5.0
# 4  108991152262655788985            Song Ro  1611028304034     4.0
#
#                                                text  pics  resp  \
# 0                              Nice people\nhelpful  None  None
# 1  They make Korean traditional food very properly.  None  None
# 2                          This food is delicious 😁  None  None
# 3                                              None  None  None
# 4                                              None  None  None
#
#                                  gmap_id
# 0  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 4  0x80c2cf163db6bc89:0x219484e2edbcfa41

# %%
meta_df.head()
# Out:
#                                        name  \
# 0                              City Textile
# 1                              San Soo Dang
# 2             Matrix International Textiles
# 3  Black Tie Ski Rental Delivery of Mammoth
# 4                           Angel-A Massage
#
#                                              address  \
# 0  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 1  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 2  Matrix International Textiles, 1363 S Bonnie B...
# 3  Black Tie Ski Rental Delivery of Mammoth, 501 ...
# 4  Angel-A Massage, 5329 Dewey Dr, Fair Oaks, CA ...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 2  0x80c2cf163db6bc89:0x219484e2edbcfa41        None  34.015505 -118.181839
# 3  0x80960c29f2e3bf29:0x4b291f0d275a5699        None  37.638754 -118.966055
# 4  0x809adef58ae560bd:0x83412889e022ff70        None  38.662630 -121.308639
#
#                                             category  avg_rating  \
# 0                                 [Textile exporter]         4.5
# 1                                [Korean restaurant]         4.4
# 2                                     [Fabric store]         3.5
# 3     [Ski rental service, Snowboard rental service]         5.0
# 4  [Massage spa, Chiropractor, Massage, Massage t...         4.3
#
#    num_of_reviews price                                              hours  \
# 0               6  None                                               None
# 1              18  None  [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 2               6  None  [[Thursday, 8:30AM–5:30PM], [Friday, 8:30AM–5:...
# 3              34  None  [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 4               6  None  [[Thursday, 9:30AM–9:30PM], [Friday, 9:30AM–9:...
#
#                                                 MISC                 state  \
# 0                                               None              Open now
# 1  {'Service options': ['Takeout', 'Dine-in', 'De...     Open ⋅ Closes 6PM
# 2  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 5:30PM
# 3  {'Accessibility': ['Wheelchair accessible entr...     Open ⋅ Closes 5PM
# 4                                               None  Open ⋅ Closes 9:30PM
#
#                                     relative_results  \
# 0  [0x80c2c624136ea88b:0xb0315367ed448771, 0x80c2...
# 1  [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 2  [0x80c2cf042a5d9561:0xd0024ad6f81f1335, 0x80c2...
# 3  [0x80960dcd6ba76731:0x9a6875ced2f9228e, 0x8096...
# 4  [0x809adee9ac6f1bd7:0xe2e56d16919b9b8d, 0x809a...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...
