# %%
# Libraries
import pandas as pd

# %%
# Load the combined dataset

df = pd.read_csv("~/teams/z12/sampled_data/combined_California_5pct.csv")
print(f"DataFrame shape: {df.shape}")
df.head()
# Out:
# /tmp/ipykernel_3232/86281969.py:3: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("~/teams/z12/sampled_data/combined_California_5pct.csv")
# DataFrame shape: (3532086, 22)
#         user_id       name_review           time  rating text pics resp  \
# 0  1.111677e+20      Javier Perez  1524515066787     5.0  NaN  NaN  NaN
# 1  1.111677e+20      Javier Perez  1524515066787     5.0  NaN  NaN  NaN
# 2  1.075599e+20          Jung Lee  1601414899163     5.0  NaN  NaN  NaN
# 3  1.075599e+20          Jung Lee  1601414899163     5.0  NaN  NaN  NaN
# 4  1.011153e+20  Dinora Colindres  1611950450362     1.0  NaN  NaN  NaN
#
#                                  gmap_id                  name_business  \
# 0  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9                   City Textile
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9                   City Textile
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49                   San Soo Dang
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49                   San Soo Dang
# 4  0x80c2cf163db6bc89:0x219484e2edbcfa41  Matrix International Textiles
#
#                                              address  ...   longitude  \
# 0  City Textile, 3001 E Pico Blvd, Los Angeles, C...  ... -118.215290
# 1  City Textile, 3001 E Pico Blvd, Los Angeles, C...  ... -118.215290
# 2  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  ... -118.292130
# 3  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  ... -118.292130
# 4  Matrix International Textiles, 1363 S Bonnie B...  ... -118.181839
#
#                 category  avg_rating num_of_reviews  price  \
# 0   ['Textile exporter']         4.5              6    NaN
# 1   ['Textile exporter']         4.5              6    NaN
# 2  ['Korean restaurant']         4.4             18    NaN
# 3  ['Korean restaurant']         4.4             18    NaN
# 4       ['Fabric store']         3.5              6    NaN
#
#                                                hours  \
# 0                                                NaN
# 1                                                NaN
# 2  [['Thursday', '6:30AM–6PM'], ['Friday', '6:30A...
# 3  [['Thursday', '6:30AM–6PM'], ['Friday', '6:30A...
# 4  [['Thursday', '8:30AM–5:30PM'], ['Friday', '8:...
#
#                                                 MISC                 state  \
# 0                                                NaN              Open now
# 1                                                NaN              Open now
# 2  {'Service options': ['Takeout', 'Dine-in', 'De...     Open ⋅ Closes 6PM
# 3  {'Service options': ['Takeout', 'Dine-in', 'De...     Open ⋅ Closes 6PM
# 4  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 5:30PM
#
#                                     relative_results  \
# 0  ['0x80c2c624136ea88b:0xb0315367ed448771', '0x8...
# 1  ['0x80c2c624136ea88b:0xb0315367ed448771', '0x8...
# 2  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 3  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 4  ['0x80c2cf042a5d9561:0xd0024ad6f81f1335', '0x8...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Column descriptions
# **user_id** - ID of the reviewer
# **name** - name of the reviwer
# **time** - time of the review (unix time)
# **rating** - rating of the business
# **text** - text of the review
# **pics** - pictures of the review
# **resp** - business response to the review including unix time and text of the response
# **gmap_id** - ID of the business
# **name** - name of the business
# **address** - address of the business
# **gmap_id** - ID of the business
# **description** - description of the business
# **latitude** - latitude of the business
# **longitude** - longitude of the business
# **category** - category of the business
# **avg_rating** - average rating of the business
# **num_of_reviews** - number of reviews
# **price** - price of the business
# **hours** - open hours
# **MISC** - MISC information
# **state** - the current status of the business (e.g., permanently closed)
# **relative_results** - relative businesses recommended by Google
# **url** - URL of the business
